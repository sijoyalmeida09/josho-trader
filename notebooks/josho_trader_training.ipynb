# %% [markdown]
# # JoSho Trader — ML Training Notebook
# Run on Google Colab (free GPU) for faster training.
#
# ## Setup

# %%
# Clone the repo
# !git clone https://github.com/sijoyalmeida09/josho-trader.git
# %cd josho-trader
# !pip install -q xgboost lightgbm pandas numpy ta scikit-learn yfinance jugaad-data pyotp

# %%
# Download fresh data (5yr daily + hourly)
# !python -m src.market_data.data_fetcher
# !python fetch_free_data.py summary

# %%
# Train V2 models (all 11 symbols)
# !python -m src.ml.train_v2

# %%
# Train V3 models (Alpha158 features, 5yr data)
# !python -m src.ml.train_v3

# %%
# Run ALL algorithms comparison
# !python -m src.ml.train_all_algorithms --all-symbols

# %%
# Run high win-rate pattern backtests
# !python run_high_winrate_backtest.py

# %%
# Save trained models to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# !cp -r data/models/ /content/drive/MyDrive/josho-trader-models/
print('Models saved to Google Drive!')
